# %%
# !pip install rouge
# !pip install SentencePiece
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 12.9 MB/s eta 0:00:00
# ...

# %%
from rouge import Rouge
from nltk.tokenize import word_tokenize
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM


file_path = '/content/url_1175.txt'

# Đoạn văn bản gốc
with open(file_path, 'r', encoding='utf-8') as file:
    sentence = file.read()


# tokenizer1 = AutoTokenizer.from_pretrained("toanduc/vit5-base-vietnews-summarization-finetuned-sport-vietnamese")
# model1 = AutoModelForSeq2SeqLM.from_pretrained("toanduc/vit5-base-vietnews-summarization-finetuned-sport-vietnamese")

# tokenizer2 = AutoTokenizer.from_pretrained("toanduc/bartpho-syllable-finetuned-sport-vietnamese")
# model2 = AutoModelForSeq2SeqLM.from_pretrained("toanduc/bartpho-syllable-finetuned-sport-vietnamese")

# tokenizer3 = AutoTokenizer.from_pretrained("toanduc/vit5-base-summarization-finetuned")
# model3 = AutoModelForSeq2SeqLM.from_pretrained("toanduc/vit5-base-summarization-finetuned")


tokenizer4 = AutoTokenizer.from_pretrained("toanduc/mT5_multilingual_XLSum-finetuned-sport-vietnamese-1")
model4 = AutoModelForSeq2SeqLM.from_pretrained("toanduc/mT5_multilingual_XLSum-finetuned-sport-vietnamese-1")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:72: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/833 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/16.3M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/416 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/937 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.33G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/234 [00:00<?, ?B/s]

# %%
inputs = tokenizer1.encode("summarize: " + sentence, return_tensors="pt", max_length=512, truncation=True)

summary_ids1 = model1.generate(inputs, max_length=150, length_penalty=2.0, num_beams=4, early_stopping=True)
summaryt5 = tokenizer1.decode(summary_ids1[0], skip_special_tokens=True)

# %%
inputs = tokenizer2.encode("summarize: " + sentence, return_tensors="pt", max_length=512, truncation=True)

summary_ids2 = model2.generate(inputs, max_length=150, length_penalty=2.0, num_beams=4, early_stopping=True)
summarybart = tokenizer2.decode(summary_ids2[0], skip_special_tokens=True)

# %%
inputs = tokenizer3.encode("summarize: " + sentence, return_tensors="pt", max_length=512, truncation=True)

summary_ids3 = model3.generate(inputs, max_length=150, length_penalty=2.0, num_beams=4, early_stopping=True)
summaryt5_new = tokenizer3.decode(summary_ids3[0], skip_special_tokens=True)

# %%
inputs = tokenizer4.encode("summarize: " + sentence, return_tensors="pt", max_length=512, truncation=True)

summary_ids4 = model4.generate(inputs, max_length=150, length_penalty=2.0, num_beams=4, early_stopping=True)
summarymt5 = tokenizer4.decode(summary_ids4[0], skip_special_tokens=True)

# %%
print(summaryt5)
# Out:
# Manchester United (MU) đang lên kế hoạch lấy cầu thủ Jude Bellingham từ Real Madrid, Chelsea hỏi mua Rafael Leao và Barca muốn có Bellerin là những tin bóng đá chính hôm nay, 23/8. MU cũng lên kế hoạch xây dựng đội hình tương lai với mục tiêu Jude Bellingham, cầu thủ 19 tuổi xuất sắc nhất hiện nay.

# %%
print(summarybart)
# Out:
# MU đàm phán lấy Jude Bellingham từ Dortmund, Chelsea hỏi mua Rafael Leao từ AC Milan và Barcelona muốn có Hector Bellerin từ Arsenal là những tin bóng đá chính hôm nay, 23/8. MU đàm phán lấy Bellingham từ Dortmund, Chelsea hỏi mua Leao từ AC Milan và Barcelona muốn có Bellerin từ Arsenal là những tin bóng đá chính hôm nay, 23/8. MU đang tập trung toàn lực cho tuần cuối thị trường chuyển nhượng với 3 mục tiêu cần mua sắm là Jude Bellingham, Chelsea và Barcelona.

# %%
print(summaryt5_new)
# Out:
# Manchester United (MU) đang xem xét sự thay đổi môi trường thi đấu sau World Cup 2022 và Liverpool cũng đã ký hợp đồng với cầu thủ Jude Bellingham. MU cũng lên kế hoạch xây dựng đội hình tương lai với mục tiêu Jude Bellingham. Barca cũng có kế hoạch đón Bellerin trở lại Barcelona cần mảnh ghép bên hành lang phải và Xavi Hernandez không loại trừ đón Bellerin trở lại Barcelona.

# %%
print(summarymt5)
# Out:
# Manchester United đang đàm phán lấy Casemiro từ Real Madrid, Chelsea mua Rafael Leao vào tuần cuối thị trường chuyển nhượng với 3 mục đích cần mua. Một trong số này là Jude Bellingham. Chelsea hỏi mua Leeds United, những tin bóng đá chính hôm nay, 23/8.

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
rouge = Rouge()

# %%
scores_model1 = rouge.get_scores(summaryt5, sentence)
scores_model2 = rouge.get_scores(summarybart, sentence)

print("ROUGE scores for Model 1:", scores_model1)
print("ROUGE scores for Model 2:", scores_model2)
# Out:
# ROUGE scores for Model 1: [{'rouge-1': {'r': 0.16037735849056603, 'p': 0.9622641509433962, 'f': 0.2749326121062765}, 'rouge-2': {'r': 0.08588957055214724, 'p': 0.7636363636363637, 'f': 0.15441176288825967}, 'rouge-l': {'r': 0.16037735849056603, 'p': 0.9622641509433962, 'f': 0.2749326121062765}}]
# ROUGE scores for Model 2: [{'rouge-1': {'r': 0.1509433962264151, 'p': 0.96, 'f': 0.2608695628692108}, 'rouge-2': {'r': 0.08588957055214724, 'p': 0.7, 'f': 0.1530054625339664}, 'rouge-l': {'r': 0.14779874213836477, 'p': 0.94, 'f': 0.25543478026051514}}]

# %%
scores_model3 = rouge.get_scores(summarymt5, sentence)
print("ROUGE scores for Model 2:", scores_model3)
# Out:
# ROUGE scores for Model 2: [{'rouge-1': {'r': 0.1289308176100629, 'p': 0.9318181818181818, 'f': 0.22651933488110867}, 'rouge-2': {'r': 0.06339468302658487, 'p': 0.6739130434782609, 'f': 0.11588784889551927}, 'rouge-l': {'r': 0.12578616352201258, 'p': 0.9090909090909091, 'f': 0.22099447300265562}}]
